# %%
# %load_ext sql
# %sql duckdb:///:memory:
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# CREATE TABLE drivers AS SELECT * FROM 'seeds/drivers.csv';
# CREATE TABLE results AS SELECT * FROM 'seeds/results.csv';
# Out:
# Running query in 'duckdb:///:memory:'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM drivers LIMIT 5;
# Out:
# Running query in 'duckdb:///:memory:'
# +----------+------------+--------+------+----------+------------+------------+-------------+-----------------------------------------------------------------------------------------------------------+
# | driverId | driverRef  | number | code | forename |  surname   |    dob     | nationality |                                                    url                                                    |
# +----------+------------+--------+------+----------+------------+------------+-------------+-----------------------------------------------------------------------------------------------------------+
# |    1     |  hamilton  |   44   | HAM  |  Lewis   |  Hamilton  | 1985-01-07 |   British   |    <a href=http://en.wikipedia.org/wiki/Lewis_Hamilton>http://en.wikipedia.org/wiki/Lewis_Hamilton</a>    |
# ...
